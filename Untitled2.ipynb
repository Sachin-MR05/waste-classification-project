# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 82.0M/82.0M [00:00<00:00, 188MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/asdasdasasdas/garbage-classification/versions/2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_path = '/root/.cache/kagglehub/datasets/asdasdasasdas/garbage-classification/versions/2'

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    data_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

test_generator = datagen.flow_from_directory(
    data_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 4044 images belonging to 2 classes.
# Found 1010 images belonging to 2 classes.

# %%
train_generator = datagen.flow_from_directory(
    data_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
print(len(train_generator))
# Out:
# Found 4044 images belonging to 2 classes.
# 127

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# Load base model without the top layer
base_model = MobileNetV2(input_shape=(224, 224, 3),
                         include_top=False,
                         weights='imagenet')

base_model.trainable = False  # Freeze weights
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dense(train_generator.num_classes, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# ...

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=5
)
# Out:
# Epoch 1/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9164 - loss: 0.2493 - val_accuracy: 0.7654 - val_loss: 0.7326
# Epoch 2/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9651 - loss: 0.1465 - val_accuracy: 0.7435 - val_loss: 0.7924
# Epoch 3/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9826 - loss: 0.0982 - val_accuracy: 0.7773 - val_loss: 0.7012
# Epoch 4/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.9916 - loss: 0.0690 - val_accuracy: 0.7813 - val_loss: 0.7235
# Epoch 5/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9980 - loss: 0.0446 - val_accuracy: 0.7793 - val_loss: 0.7019

# %%
import matplotlib.pyplot as plt


plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np

x_test, y_test = next(test_generator)
index_to_plot = 1

# Prediction with base model (extract features)
pred = model.predict(x_test)

plt.imshow(x_test[index_to_plot])
plt.title(f"Predicted: {np.argmax(pred[index_to_plot])}, Actual: {np.argmax(y_test[index_to_plot])}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# 1. Unfreeze the base model
base_model.trainable = True

# 2. Recompile with a lower learning rate (important!)
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 3. Train again
fine_tune_history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=5
)
# Out:
# Epoch 1/5
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 908s 7s/step - accuracy: 0.5077 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/5
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 910s 7s/step - accuracy: 0.4978 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 3/5
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 863s 7s/step - accuracy: 0.4958 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 4/5
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 923s 7s/step - accuracy: 0.5093 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 5/5
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 849s 7s/step - accuracy: 0.4909 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6932
